# %%
a = 10
b = 5

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a/b
# Out:
# 2.0

# %%
a*b
# Out:
# 50

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 0

# %%
a = 100
b = 4

# %%
# Modulus / Reminder
a%b
# Out:
# 0

# %%
a ** b
# Out:
# 100000000

# %%
# BODMAS

print((5*5)-9+7/8)
# Out:
# 16.875

# %%
print (4+(8**2)-3*3%1)
# Out:
# 68
