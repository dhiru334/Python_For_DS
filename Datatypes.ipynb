# %%
# Datatypes

name = 'mike'
print(name)
# Out:
# mike

# %%
name = input('enter ur name')
# Out:
# enter ur name dhiru

# %%
print(name)
# Out:
# dhiru

# %%
a = True
b = 'True'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
#  # Typecasting

# %%
var = 3
type(var)
# Out:
# int

# %%
var1 = float(var)
print(var1)
type(var1)
# Out:
# 3.0
# float

# %%
var = 4.9
var_int = int(var)
print(var_int)
print(type(var_int))
# Out:
# 4
# <class 'int'>

# %%
var = 2
new_var = str(var)
print(type(new_var))
# Out:
# <class 'str'>

# %%
new_var
# Out:
# '2'

# %%
string_var = "2.5"
float_var = float(string_var)
int_var = int(float_var)
print(int_var)
print(type(int_var))
# Out:
# 2
# <class 'int'>

# %%
string_var = "3.3"
int_var = int(float(string_var))
print(int_var)
print(type(int_var))
# Out:
# 3
# <class 'int'>

# %%
x = 9.9
print(float(int(x)))
# Out:
# 9.0

# %%
name = 'dheeraj'
print(name)
# Out:
# dheeraj
